# %%
import os
import numpy as np
import re
import matplotlib.pyplot as plt
import random
from pathlib import Path

# %%
# input files 
#
danish = 1
if danish:
    file_1 = r'C:\DTU\Data\201901_JanuaryExpt\Sentences\difficult_D.txt'
    file_2 = r'C:\DTU\Data\201901_JanuaryExpt\Sentences\easy_D.txt'
else:
    file_1 = r'C:\DTU\Data\201901_JanuaryExpt\Sentences\difficult_E.txt'
    file_2 = r'C:\DTU\Data\201901_JanuaryExpt\Sentences\easy_E.txt'

#resultPath = r'M:\Documents\Experiment design\Sentences\Danish sentences\Leipzig Corpora - Study2\Analyzed_Patients'

# %%
config = Path(file_1)
if config.is_file():
    fSentences = open(file_1, encoding='utf-8')

    sentences_D = fSentences.readlines()
    if sentences_D is not None:
        print('1')
    


config = Path(file_2)
if config.is_file():
    fSentences = open(file_2, encoding='utf-8')

    sentences_E = fSentences.readlines()
    if sentences_E is not None:
        print('2')
    
print(len(sentences_D), len(sentences_E))
# Out:
# 1
# 2
# 50 50

# %%
def ComputeLIXscoreOfPhrase(phrase):
    B = 1
    sentenceLength = phrase.count(' ')
    words = phrase.split()
    A = sentenceLength
    C = 0
    for word in words:
        if len(word) > 6:
            C = C + 1
    
    LIX = A/B + (C*100)/A
    
    #if LIX < 35:
    #    print('Easy')
    #elif LIX > 45:
    #    print('Difficult')
    #else:
    #    print('Medium')
    
    return LIX

# %%
for sentence in sentences_D:
    #print(sentence)
    
    # for lix score, numbers, symbols are considered as spaces
    #print(sentence)
    # replace numbers and commas with spaces
    sentenceForLix = re.sub('[",:;()/\-?!.]', " ", sentence)
    sentenceForLix = re.sub("[0-9]+.?[0-9]*", " ", sentence)
    
    #print(sentenceForLix)
    # compute LIX score
    LIX = ComputeLIXscoreOfPhrase(sentenceForLix)
    print(sentence, LIX)
    #print(LIX)
# Out:
# Alligevel er to tidligere korrespondenter i USA med indgående kendskab til amerikanske forhold ikke i tvivl om hvilken sang, de vælger til at karakterisere situationen.
#  65.66666666666666
# Bryghusets hjemmeside beskriver godt de forskellige typer øl.
#  64.14285714285714
# Guiteau begyndte herefter at interessere sig for politik.
#  78.42857142857143
# Haderslev Kunstforening samarbejder med Museum Sønderjylland-Arkæologi Haderslev ved større og længerevarende udstillinger evt. kombineret med foredrag, samt ved afholdelse af den årlige generalforsamling.
#  72.0
# Transport er i visse tilfælde inkluderet i de anvendte aggregerede data for produktion af råvarer fx polystyren.
#  66.0
# Kaeline Fugtgivende dagcreme med arganolie balancerer og beskytter mod hverdagens miljøpåvirkninger.
#  90.0
# Pengene bliver skåret fra ulandshjælpen, og græsrødder frygter misbrug og korruption.
#  70.0
# Indholdet i hæftet bygger blandt andet på erfaringer med formaliseret pårørendesamarbejde i Region Syddanmark og Vejle, Aalborg og Roskilde Kommune.
#  61.10526315789474
# Journalisterne Rikke Bergquist og Camilla Markvardsen introducerer filmen med en personlig beretning om mødet med immigranter i Mexico.
#  69.94117647058823
# Personer, der har bopæl i Danmark, kan som hovedregel ikke benytte en udenlandsk indregistreret bil til kørsel her i landet.
#  55.8421052631579
# Alle ungeaktører og deres ledere i Thisted Kommune skal på sigt kender til tankerne bag uddannelsesgarantien og de fælles aftaler omkring garantiens omsætning til en fælles praksis.
#  64.46153846153845
# Bybilledet i Flensborg var i denne periode præget af afstemningsplakater, æresporte, demonstrationer og overalt de nationale flag, som kom til at spille en stor rolle i agitationen.
#  60.61538461538461
# Sara Paretsky skriver med stort samfundsengagement og fin fornemmelse for det specifikt kvindelige, som hendes heltinde kan tilføje krimigenren.
#  68.0
# Traditionelt sættes fokus på implementering af dyre og komplekse IT-og konsulentløsninger, som ikke tilgodeser eller optimerer arbejdet for brugerne, men i højere grad skaber frustration og kompleksitet i arbejdsgangene.
#  67.28571428571428
# Pengene bliver skåret fra ulandshjælpen, og græsrødder frygter misbrug og korruption.
#  70.0
# Lysledere overfører målesignalerne til registreringsenheen, som er installeret i en separat styretavle.
#  74.63636363636363
# Maeva Cannes Verrerie er et familievenligt ferieområde med 2 gode pool-områder, tæt på indkøbsmuligheder, caféer, restauranter og ikke mindst Middelhavet.
#  61.10526315789474
# Gudstjenesten fortsætter i kirken.
#  103.0
# Han er fængslet fordi han ligesom Jesus opfattes som en politisk trussel, men Herodes tøver med at efterkomme jødernes krav om hans henrettelse.
#  62.90909090909091
# Tranzaura har hovedsæde i Limerick og er en ung, innovativ virksomhed, der udbyder teknologiske løsninger til transportsektoren.
#  72.25
# Al den information der sendes via disse celler, igennem synsnerven til hjernens visuelle cortex hvor den afkodes, er kun undervejs i få picosekunder.
#  62.90909090909091
# Bygningen har et arkitektonisk udtryk, rumdisponering og materialitet, hvor religion, kultur og stedets karakteristiske naturrum samles til et hele.
#  68.0
# Ejendomsforeningen Danmark arrangerede i går et gåhjemmøde med rundvisning på stedet.
#  70.0
# For tiden arbejder Patientforum på at etablere et videnscenter for opsamling af patienterfaringer - en idé, som er blevet positivt modtaget af Sundhedsministeriet.
#  62.90909090909091
# Justerbar børstehastighed kan fås som tilbehør og gør det endnu nemmere at bruge maskinen på alle overflader og under alle forhold, med fremragende resultat.
#  62.130434782608695
# Kasserne fra pakkebåndet stakkes på pallen, hvorefter den fyldte palle køres til udlevering.
#  62.0
# Landbrugets stigende forbrug af sprøjtemidler skal være slut.
#  64.14285714285714
# Perioden omkring 1800, der så den fulde etablering af europæisk magt og tilstedeværelse i Indien, så også begyndelsen på den moderne indologi, dvs. den videnskabelige undersøgelse og objektivisering af Indiens fortid.
#  76.16129032258064
# Så er webarkivering i Danmark ikke længere et nichefænomen, som kun interesserer internetforskere.
#  62.0
# Træningen foregik på eksercermarken ved kirkegården, bag ved Odense Sygehus.
#  64.55555555555556
# Aftenens kamp bød på genvalg på starterpladsen til Sam Cassell fra Minnesota, der i kampene efter hans skade har været henvist til bænken af Anthony Carter.
#  61.0
# Cookies, der er nødvendige for webstedets funktionalitet og ydelsen af de tjenester, du har anmodet om, vil fortsat fungere, uanset om du har afgivet dit samtykke eller ej.
#  67.74074074074073
# Da de ”nationalt sindede” borgerlige partier gik ind i samlingsregeringen, krævede de strejkeforbud.
#  70.33333333333334
# Forudseende kørsel fungerer også baglæns.
#  79.0
# Græske tilstande venter i landet med verdens dyreste offentlige sektor og verdens højeste skattetryk hvor de produktive nu er i mindretal medens alle dem med snablerne i de offentlige kasser er i flertal!
#  69.5
# Indhold om Digital Post fritagelse opdateret fra 1. marts 2014 kan borgerne søge om tildeling af læseadgang til pårørende eller fritagelse fra Digital Post hos kommunerne.
#  68.3076923076923
# Lyngy-Taarbæks borgmester, Rolf Aagard Svendsen, afviser, at tilladelsen blev givet, fordi Messerschmidt pressede på.
#  66.84615384615384
# Organisationen er kommet i besiddelse af tre videoer, der viser egyptiske fanger, som tilsyneladende er blevet tortureret og derefter dræbt.
#  61.10526315789474
# Pengene havde kun eksisteret som fiktive beløb i pengeinstituttets bogholderi.
#  64.55555555555556
# Advokat og partner i Brandt & Lauritzen, Jon Lauritzen, er blevet beskikket som bisidder i forbindelse med Skattesagskommissionen.
#  64.05882352941177
# Aftalen indebærer blandt andet, at universitetsområdet tilføres 682 mio.kr. til styrkelse af forskeruddannelsen, at den strategiske forskning tilføres 1.231 mio.
#  70.0
# Da der er brugt Rainforest Alliance Certified kaffebønner, hjælper hver kop kaffe landbrugssamfund til at bygge en bedre fremtid og beskytte miljøet.
#  63.857142857142854
# Foruden boligerne følger der bl.a. også infinity pool, vandfly, fitnesscenter og Helipad med i prisen.
#  64.0
# Indklagede indsatte herefter 1.520 kr.
#  65.0
# Lydbånd, der gengiver frilæsningsbøgerne, kan anvendes til en individualisering af elevernes arbejde.
#  74.63636363636363
# Perioden omfatter detailplanlægning og realisering, og status er, at man netop har haft en række projekter omhandlende friarealforbedringer til offentlig høring.
#  65.0
# Transport formidles, vi har aftaler med vognmænd, der leverer træet med kranbil eller container til en fornuftig pris.
#  64.05882352941177
# Ejendommen består af 3 soveværelser, 2 badeværelser, stue, spisestue, separat køkken, overdækket terrasse, garage og opbevaringsrum.
#  75.0
# Indsamling af biologisk materiale, analyse af blod samt opbevaring af blod i biologisk bank blev varetaget af Klinisk Biokemisk Afdeling på Rigshospitalet.
#  73.38095238095238
# Journalister trænger ind i Libyen Udenlandske journalister begynder at rapportere fra den nordlige del af Libyen, hvor oprørerne har overtaget kontrollen.
#  75.0

# %%
for sentence in sentences_E:
    #print(sentence)
    
    # for lix score, numbers, symbols are considered as spaces
    #print(sentence)
    # replace numbers and commas with spaces
    sentenceForLix = re.sub('[",:;()/\-?!.]', " ", sentence)
    sentenceForLix = re.sub("[0-9]+.?[0-9]*", " ", sentence)
    
    #print(sentenceForLix)
    # compute LIX score
    LIX = ComputeLIXscoreOfPhrase(sentenceForLix)
    print(sentence, LIX)
# Out:
# Jo længere den kører, jo mere umuligt bliver det at slette den.
#  29.181818181818183
# Landet er opdelt i 4 regioner, henholdsvis nord, øst, syd og midt.
#  29.181818181818183
# Så så man lige mig ligge der i en fin lille engangspapirtrusse.
#  20.090909090909093
# Tej er ikke så glad for andre hunde.
#  7.0
# Alle og enhver er altså med til at forme det samfund, vi lever i.
#  21.142857142857142
# Enhver kan sige noget, som kan bruges af andre.
#  8.0
# Da de åbner 08:30 nåede der lige at komme en før mig.
#  12.0
# Hånden på hjertet, hvor mange af jer ejer så en eller måske flere symaskiner?
#  28.384615384615387
# Indrykker man en annonce på I LOVE IKEA, er der god chance for at den bliver læst.
#  28.5
# Håber at du kan bruge noget af det og god bedring.
#  20.0
# Abba tølter bare nemt derud af.
#  5.0
# Ærgerligt at det er så tissekoldt, at ingen kommer til at se det.
#  28.666666666666668
# Efter noget tid havde han brugt den til både computerbordet og som sofa.
#  20.333333333333336
# Fortæl læreren, at du har sagt sådan til hende.
#  20.5
# Gud er vores Herre, såvel som jeres.
#  6.0
# Under alle omstændigheder så held og lykke.
#  22.666666666666668
# Varm 1 spsk olie op på én stor eller to mindre pander.
#  20.090909090909093
# Smut mandlerne og rist dem til de begynder at tage farve på en tør pande.
#  28.285714285714285
# Så nu males bilen i 1 farve - nemlig en lækker orange.
#  20.090909090909093
# Han bliver hjemme i Hannover.
#  29.0
# Af alle grimme fodboldtrøjer, vil mange nok mene at det her er en klar vinder.
#  28.285714285714285
# Forklar hvad der skal laves.
#  29.0
# Egon Spens er ved at sminke sig til klovnentreen.
#  20.5
# Først og fremmest har offensiven været noget af det bedste i mands minde.
#  28.666666666666668
# Gud vender sig mod Eva: ”Har du spist af frugten”.
#  20.11111111111111
# Han blev født den 4. august 1747, og som faderen gik han ind i flåden i en meget ung alder.
#  25.761904761904763
# Pippis hest kan næsten kun være en knabstrupper.
#  21.285714285714285
# Sæt dem da i haven og se hvad der sker.
#  9.0
# Åh nej - der blev vist lige skabt et behov der.
#  10.0
# Håber nogen kan hjælpe mig på vej.
#  6.0
# Altså en reel mulighed for at lægge til, også i flere dage.
#  20.090909090909093
# Efter nogen tid kom så champagnen som vi kender den i dag til.
#  20.333333333333336
# For tre uger siden var den til dyrlæge 3 mdr. Der vejede hun 10.5 kg.
#  21.666666666666668
# Gruppen har travlt med de store flytninger, men er ellers godt med.
#  29.181818181818183
# Guldet i London bragte hendes sejrsstime op på 470 kampe uden nederlag.
#  29.181818181818183
# Håber at se jer til lidt hygge og samvær.
#  20.5
# Lyng og mos blev brugt meget.
#  5.0
# Maden var så lækker og alle gæsterne skulle vide hvem der havde leveret.
#  28.666666666666668
# Ørene er små og hænger.
#  29.0
# Perfekt til en chic fest, som servietholder eller som noget helt andet.
#  29.181818181818183
# Gud kan forvandle noget ondt til noget godt.
#  21.285714285714285
# Han blev fornærmet og sagde, at han blot gjorde sit job.
#  20.0
# Pige på tolv kvalt og smidt i grøften.
#  21.285714285714285
# Sæt fadet i ovnen i ca. 30 min.
#  7.0
# Træsko kan udleveres gratis ved behov, hvis du er ansat i klinikken mere end 6 mdr.
#  28.333333333333336
# Slut Mac mini til fjernsynet for at se dvd'er eller film.
#  20.0
# Af udvalget må der vælges 2 slags stege, - hvis ekstra steg ønskes koster det kr 20,- pr. person.
#  29.526315789473685
# Aldrig har jeg set et hold brænde så mange store chancer.
#  20.0
# Rengør med varmt vand og tør grundigt af.
#  21.285714285714285
# Overskuddet før skat blev på 8 mio. 22.666666666666668

# %%
for i in LIXDifficultList:

    print(i)
# Out:
# 130 Erik Nielsen i Resdal. 19.6.1767, fol.340B.
#
# 2. Fyld: Skræl æblerne, og skær i mindre stykker.
#
# 986 Birgitte Nielsdatter i Tvingstrup. 30.1.1781, side 514.
#
# Af den grund har 12 familier dannet Rødding Sø Fåreholderlaug.
#
# Af egen erfaring ved jeg, hvor destruktivt og opslidende det er.
#
# Afgrænsningen mellem farverne er ikke skarp nok i de lodrette skift.
#
# Af mel og fedtstof laves en afbagning der spædesmed suppe.
#
# Af ukendte årsager vil den ene sort undertrykke de to andre.
#
# Alfa-Omega har mere end 15 års erfaring inden for laboratorieindretning.
#
# Alle disse betingelser er nødvendige, og de findes kun ved Øresund.
#
# Alle syntes, ligesom jeg, at det var en sjov idé.
#
# Alle vores spillere har vist klassespil, som lover godt for fremtiden..
#
# Alligevel var der grund til at glæde sig til aftenens træning.
#
# Andelen af ikke-brugere svinger mellem 15 % og 27 %.
#
# Åndsfrihed i dette årti giver udfordringer, når det skal praktiseres.
#
# Appelsinsaft, vin og andebouillon tilsættes og saucen koges lidt ind.
#
# Både stængel og blade har et smukt blågrønt, petrolfarvet skær.
#
# Balsamisk eddike i små mængder er meget fint til blommer.
#
# Begge typer samarbejde skal Innovationsprisen være med til at accelerere.
#
# Begrebet er udvandet, og har vel egentlig altid været det.
#
# Belgieren Boonen vandt for femte gang løbet E3 Harelbeke i Flandern.
#
# Beskyt bagsiden af din iPad med plast i smarte farver.
#
# Besøg vores flotte hjemmeside allerede idag, og find mere information.
#
# Beton skaber ro og spiller godt sammen med boligens arkitektur.
#
# Bolche budskabs blanding. ca. 95 gram mod, frihed, håb og tanke.
#
# Børnene glæder sig bare så meget til vi skal afsted.
#
# Boss' dobbelt pedaler virker ligeså solide som deres enkelt pedaler.
#
# Ca 5-10 min inden retten er færdig tilsættes grøntsagerne.
#
# Ca 80% af børnene bliver tørre på behandling med ringeapparat.
#
# Converse sko lilla, hummel flyverdragt udsalg Rige mænd og fattige mænd.
#
# Corou bestod Politihunde kåringen i dag ved Slagelse PH klub!
#
# Corydon og Ziegler siger, at en konflikt skal gøre ondt.
#
# Dagen efter var parolen mod nazi-marchen "Dortmund stellt sich quer!"
#
# Da kolonitiden endte blev området delt mellem Egypten og Sudan.
#
# De bedste hilsner og på gensyn fra Thorkild og Anton.
#
# De er alle ingredienserne i den fede danske tegneserie Deadboy.
#
# De er brede ved basis og let afrundede i spidsen.
#
# De gode ideer svæver konstant rundt i periferien af ens synsfelt.
#
# De levede i militært organiserede, frie fællesskaber under en valgt leder.
#
# Den 20. maj blev den nye lystbådehavn ved Udbyhøj indviet.
#
# Den 9. april henter vi igen storskrald fra private husstande.
#
# Den danske landsholdsrekord står Kasper Schmeichels far Peter Schmeichel for.
#
# Den fik også en hel masse flotte knopper og blomster..
#
# Den første hvide by vi besøger er byen Benalmadena Pueblo.
#
# Denne bog dækker, hvordan man gør den del af jobbet korrekt.
#
# Denne chili smager som den almindelige jalapeno, men er noget mildere.
#
# Denne del kaldes for ”Englenes Andel” – ”The Angel’s Share”.
#
# Denne Klasse er endog mere påvirket i så Henseende end Modpartiet.
#
# Den otte år gamle sag om lille Camillas forsv­inden væk.
#
# Den øvrige økonomi klares med overskuddet fra tennisklubben til grus etc.
#
# Den rene koldbryggede kaffe serveres i en glas med isterninger.
#
# Den sidste Venus-passage var i juni 2004 (billede under Astro-fotogruppen).
#
# Den travle duo spiller på fredag i Pakhuset i Århus.
#
# Der blev i alt udskiftet ca. 750 vinduer og døre.
#
# Der er 5 høringssvar, der har forholdt sig til forslaget.
#
# Der er åbenlyse konfliktende interesser der er på spil her!
#
# Der er altid chancer for mindre makrelarter eller sjove bundfisk.
#
# Der er derfor ikke grundlag for erstat- ning for markedsfortrængning.
#
# Der er dog uenighed om, hvad der foregik på mødet.
#
# Der er ikke mulighed for blodprøvetagning ved de sene konsultationer.
#
# Der er nogle få danismer i besvarelsen og nogle få stavefejl.
#
# Der er opsat plancher i vore motionsrum til råd og vejledning.
#
# Der findes ikke dårligt vejr, der findes kun elendige ordsprog.
#
# Derfor efterlyser vi en masse garnrester, som vi kan bruge.
#
# Derfor er bynære skove højt prioriteret i den statslige skovrejsning.
#
# Derfor er det også let at overvåge temperaturen i ovnen.
#
# Derfor løber jeg meget sjældent en lang tur fredag eftermiddag.
#
# Derfor skal ejere af fjerkræ og fugle nu følge smitteforebyggende regler.
#
# Der laves forskellige ture alt efter årstid, vejr og ønsker.
#
# Der skal lyde et stort tillykke til spillerne på holdet.
#
# Desuden har det tre gange så stor bøjningsstyrke som nordisk træ.
#
# Det betød at speakningen blev indstillet pga. vand i strømanlægget.
#
# Det bliver forhåbentligt et kredsløb med mange deltagere til følge.
#
# Det er den vej som politikerne bruger i denne tidsperiode.
#
# Det er der jo lavet en del psykologiske undersøgelser af.
#
# Det er det tredje af stævnerne jeg stiller op til.
#
# Det er egentlig nok noget, som altid har været tilstede.
#
# Det er gode nyheder for naturen og de lokale befolkninger.
#
# Det er ikke nok at eleverne/de studerende kan surfe på Internettet.
#
# Det er kort sagt et gennemført og lækkert metalcore album.
#
# Det er ofte op til den enkelte boligejer selv at vurdere.
#
# Det er også kun fordi manden indimellem opfører sig SÅ barnligt.
#
# Det første vi ser, når vi møder hinanden er ansigtet!
#
# Det fremkalder en reaktion, som vi så i 2001.
#
# Det har helt bestemt været en dejlig tur til London.
#
# Det hører til sjældenhederne at der benyttes halvfabrikata eller. lign.
#
# Det kan både være et unormalt højt forbrug eller dårlig afkøling.
#
# Det kan hverken ønsketænkning eller dagdrømmerier ændre en tøddel ved!
#
# Det kan ikke være statens opgave, at grund opdrage deres børn.
#
# Det kan også hjælpe at løfte saddelspidsen et par millimeter.
#
# Det kan virke motiverende, at ens arbejdsplads interesserer sig for en.
#
# Det kom COMSNMG1 til at opleve mellem ATHABASKAN og PETER TORDENSKIOLD.
#
# Det kræver blot, at du har en Software Assurance-aftale (SA).
#
# Det menneskelige ligger ikke kun i den enkelte, men mellem menneskerne.
#
# De to danske herrer leverede pæne resultater, men ikke deres bedste.
#
# Det samme gør sig gældende når det kommer til anti-nazi demonstrationer.
#
# Det synspunkt kunne man også høre ved kaffebordene i pausen.
#
# Dette er et udkast til et redesign af en Højskoles hjemmeside.
#
# Dette giver en relativ lav vægt og stor slidstyrke på stoffet.
#
# Det var prægestemplet til bagsiden af femdobbelt dukat 1704.
#
# Det vil dog stadig være koordinatoren, der indbyder samt arrangere mødet.
#
# Det ville være det frækkeste og vildeste jeg kunne forestille mig.
#
# Det vil være umuligt for mig at anbefale en konkret model.
#
# Disneys 33. klassiker fås nu for første gang på Blu-ray.
#
# DR og Information har netop lanceret kampagnen ”Hvad gør vi nu?
#
# Drømmen om at se børnene spille fodbold på den store plæne?
#
# Drys med timian (jeg brugte tørret) og en god håndfuld peberkorn.
#
# Du får adgang til app´en som kan overvåge dit søvnmønster.
#
# Du får smertestillende medicin med hjem til de første dage.
#
# Du forenkler arbejdsprocessen og sparer tid ved at bruge dette synshjælpemiddel.
#
# Du forstår sikkert allerede, hvad det her går ud på.
#
# Du kan finde en tabeloversigt over de opbragte skibe her.
#
# Du kan her læse mere om kognitiv adfærdsterapi for spiseforstyrrelser.
#
# Du risikerer endda, at de er dyrere end i Danmark.
#
# Du vil modtage en bekræftigelse på din booking, på mail.
#
# En elegant skål som tager sig flot ud i hjemmets indretning.
#
# En genopfriskning hvert andet eller tredje år er anbefalings værdig.
#
# Enten som forbedring fra sælger eller som forbedring for mig.
#
# Er det ikke at gøre livet besværligt for forbrugerne og virksomhederne?
#
# Er I to eller flere personer, kan der gives grupperabat.
#
# Et fortryllende slot med tårne, spir, voldgrav og en smuk slotspark.
#
# Et landskab, som vi næppe troede fandtes på vor klode.
#
# Et lille springvand kan være hyggeligt i en lille dam.
#
# Et par billeder at ting der kommer med på marked.
#
# Et totalteater med dejlige og funktionelle sange af Tobias Trier.
#
# Evalueringen blev fremlagt på Byrådets møde den 27. maj.
#
# Filmplakat kr. 450,- Original dansk filmplakat 62 x 85 cm.
#
# Fixed Head Coupéen betragtes af mange som den bedste af E-typerne.
#
# For gør vi alle det, så overrasker vi – positivt.
#
# Formen på b2g Academy-uddannelsen gav også et positivt indtryk.
#
# Først og fremmest er der langt mellem tilbudene på kvalitetsoplevelser.
#
# Frank Hansen kom til Silkeborg fra Esbjerg i sommeren 2009.
#
# Garden blev oprettet i februar 1919 og nedlagt i 1922.
#
# Gaver mellem ægtefæller er dog både skattefri og fri for gaveafgift.
#
# Giv ham nu lidt aflastning så han ikke brænder ud.
#
# God fornøjelse og lad os så ”sparke røv” i Jylland.
#
# God kvalitet, lækkert design, enkel, må ikke fylde for meget.
#
# Håber du også får en rundtur om Færøerne ved indflyvningen.
#
# Halshugningen foregik på Bjergby Banke den 16. maj 1838.
#
# Halver æblerne, fjern kernehusene og skær dem i mindre stykker.
#
# Han forsøger at lave en helt lige rille i jorden.
#
# Han kom hurtigt i fejlproblemer og fik ikke meget spilletid.
#
# Han løb tilbage til det blå misfoster af et hus.
#
# Han var blevet anholdt den 23. december 1943.
#
# Han var den perfekte "storebror" for vore to andre hunde.
#
# Han vinder absolut INTET ved at spærre for de gående.
#
# Henvendelse bør ske til KommuneKredit i god tid inden udløb.
#
# Her finder du blandt andet møbler, sengetøj og dyner i børnestørrelser.
#
# Her kunne man virkelig se at der er forskel på termoruder.
#
# Her oser af god stemning og masser af lokal charme.
#
# Hos Fair DISPLAY finder du et stort udvalg af lï¿½kre displaysystemer.
#
# Hvad kan forhindre dine medarbejdere i at yde toppræstationer hver dag?
#
# Hvis I fylder helikopteren, så er prisen pr. person lavest.
#
# Hvis overfladen er meget poleret, kan gulvet også være glat.
#
# Hvis tiden og lysten tillader det, fortsætter vi mod Brede.
#
# Hvorfor føles ting af metal koldere end ting af træ?
#
# I dag er der derimod artikler om bedre sexliv og orgasmeguider.
#
# I dag er Internet en stor del af mange virksomheders markedsføring.
#
# I denne uge har Fordomsfrekvensen besøg af Antoinett, der har muskelsvind.
#
# I Filippinerne var det umuligt at finde en ny mand.
#
# I langt de fleste tilfælde kommer dine feriepenge altså ikke automatisk.
#
# I menuen Safari vælger du ”Indstillinger” og klikker på ”Sikkerhed”.
#
# Indsendt af Anne/FruFlittig kl. 13.18 Send med e-mailBlog om dette!
#
# Ingen to- eller tre-stjernede, kun fem, fire eller en stjerne.
#
# International konference i København 23.-25. august 2006.
#
# Især velegnet til brug sammen med bløde blyanter og ved kultegning.
#
# I september måned, fik vi de første digitale konvertere sat op.
#
# I vores kirke fastholder vi spædbarnedåben som det mest almindelige.
#
# Ja selv en sten består af ufattelige mængder af energi.
#
# Jeg gi'r besked, det kunne være rigtig hyggeligt at træffes!
#
# Jeg glæder mig dog nok allermest til hjemmekampen mod BIF.
#
# Jeg har et lille problem, der egentlig er super frustrerende!
#
# Jeg har lige så lidt tilovers for folk der forsøger..
#
# Jeg husker bedst JPs fremragende serie om Det Store Ejendomsspil.
#
# Jeg mærker irritation, når jeg er hjemme hos mine forældre.
#
# Jeg ved ikke om alarm feromon metoden bliver en succes.
#
# Jeg vil helt sikkert bestille den igen en anden gang.
#
# Kan fås med og uden udstyr som hydraulisk drejebar monteringshovede.
#
# Kik ind i shoppen i dag og se vores udvalg.
#
# Koncentrationsproblemerne og ADHD'en er der stadig, men i meget mindre grad.
#
# Kønnets grænser, i: Clios døtre gennem hundrede år, s. 9-12.
#
# Kontrasten mellem den tyske og den amerikanske militærkirkegård er kæmpe stor!
#
# Kunne ikke bruge Master Card som jeg foreslog og normalt bruger..
#
# Lad os derfor sammen slå en pæl igennem de fordomme.
#
# Læg farvekridt, tusch og andet tegnemateriale inden for dit barns rækkevidde.
#
# Læg løgene i efteråret og få et blomsterne flor til foråret.
#
# Lappeløsninger af det nuværende system på erhvervsskolerne er slet ikke nok.
#
# Lars Løkke fremtrådte som en person, der gerne vil samle nationen.
#
# Ledighedsprocenten er i gennemsnit for a-kasserne steget med godt ½ pct.
#
# Lie, (senior) butik med Esso benzinstanderen, den tomme byggegrund hvor Chr.
#
# Ligesom de også dækker det under vores andagter i kvindeskolen.
#
# Lineføring, fri ved fod, afsætning og indkald gik rigtig flot.
#
# Log ind her > Søg efter de billigste hoteller i Albufeira.
#
# Løkken by er en gammel fiskerby og en af kystens største.
#
# Lønnen for ansatte i vikarbureauer stiger med 4,85 procent.
#
# Loppefrøskaller opsamler evt. sand i tarmene og tager det med ud.
#
# Madrassen behøver en sådan behandling ca. 4-5 gange per år.
#
# Magtmafiaen søgte at dække over statstjenestemændenes rolle i dette snigmord.
#
# Mail: info@fleks-frederikshavn.dk Cafe i Skagen søger cafemedarbejder 20 timer ugentlig.
#
# Mange af de britiske régeringsdokumenter fra år 1939 er blevet frigivet.
#
# Måske den største nulevende, nu da Louise Bourgeois er død.
#
# Måske indeholdt den ligefrem ligene af Hitler og Eva Braun?
#
# Måske Miller har ment, at historiens alvor krævede noget comic relief.
#
# Måske oveni købet en ide til et produkt med eksportpotentiale?
#
# Meget praktisk kaffemaskine, der samtidig er pæn at se på.
#
# Men ak ja, det er åbenbart børnenes skyld det hele.
#
# Men alle interesserede er selvfølgelig velkomne til at kigge med.
#
# Men efterhånden er jeg kommet til at respektere det fuldstændigt.
#
# Men er det udfordrende nok for en topleder igennem 10 år.
#
# Men for eksempel bliver jeg vildt fascineret af dette: ".
#
# Men galanterne har et hav af ting der kan påvirke tomgangen.
#
# Men Isabella holdt jo selvfølgelig fast i at svømme løbet.
#
# Men kvinderne er ofte for bange til at anmelde mændene.
#
# Men nu rækker Det Økologiske Råd forbrugerne en hjælpende hånd.
#
# Men vi ved ikke, hvor meget de ligner vikingernes historier.
#
# Midt på kirkegulvet stod Daniel og tog imod sin prinsesse.
#
# Mindmup: Er en tjeneste hvor du kan lave online mindmapping.
#
# Min er synet i dag, dog betinget pga 2 småfejl.
#
# Min søn var i den anden ende - tydeligt oprevet.
#
# Moms Dragtpose med glidelukning Ekstra god beskyttelse af dit tøj!
#
# Musikken er også en udtryksform, som kan bruges i mange sammenhænge.
#
# Myte: Hvis du peeler din hud, skrubber du solbrunheden væk.
#
# Når m ikke længere kan være på p, skiftes til strømpep.
#
# Nede ved orgelet er anbragt et parti af det gamle alterbordspanel.
#
# Nogle arrangementer er gratis, for andre er der et deltagerbeløb.
#
# ;) Nøj hvor ser den strawberry daiquiri bare mums ud!
#
# NU – et not-for-profit mobileselskab for handicappede, som både s..
#
# Nu kan Aqua Wellness klare forbedringerne for 96.000 kroner.
#
# Nyd de sjældne fotografier, som ikke tidligere har været vist!
#
# Odense havn får i dag besøg af Transportminister Hans Christian Schmidt.
#
# Odense Stole- og Møbelfabrik havde leveret de røde hørbetukkede stole.
#
# Ofte kæmpede jeg mig igennem dagen på grund af søvnmangel.
#
# Og hvor starter man? i varme Florida eller kolde Maine?
#
# Og lad vær med at ty til de hurtige løsninger.
#
# Og sådan en lille skabning kan man jo ikke skuffe.
#
# Også i Danmark har krisen i 2008 betydet et kvalitativt skift.
#
# Og sidenhen er filmen også udkommet I flere dele af verden.
#
# Ole RøndeKlinge af Michael West, frontholk i mammut og 925S.
#
# Omgivet af store træer er her mere eller mindre permanent skygge.
#
# Omkostningerne til at drive siden, betales gennem vores mange samarbejdespartnere.
#
# Omkring 1972/73 knækkede der en stor gren af hængebøgen.
#
# Opstil saa vidt muligt et Budget, saavel for Indtægt som Udgift.
#
# Ordinær generalforsamling afholdes hvert år, anden sidste onsdag i marts.
#
# Organisationen står heller ikke til ansvar for indholdet i artiklen.
#
# Osama ser jeg gerne prøves som hængende angriber bag Lange.
#
# Os cuboideum rykkes udad-opad pï¿½ grund af peroneus senens tryk.
#
# Over 1250 deltog i dette års udgave af Frijsenborg Motion.
#
# Over 90% af akvakulturens produkter kommer fra vegetarfisk i Asien.
#
# På det tidspunkt blev jeg mindet om, hvordan te bliver brygget.
#
# På hjemturen blev endnu 3 fly skudt ned af natjagere.
#
# Panafieu stillede op for egen regning - og blev valgt.
#
# Partiet er vokset fra 47 til 57 mandater, siger han.
#
# Politiet blev ringet op af polakken selv kl. 02.25.
#
# Problemet ser ud til at blive løst den kommende uge.
#
# Proff sæt hurtig og korrekt installation (høj kvalitet)… læs mere..
#
# Randzonen skal slås mindst én gang årligt eller alternativt afgræsses.
#
# Sabrina Bøje Nielsen på Felixgårds Felix Iki vandt LB. 08.04.
#
# Sådan lyder ordene fra skoleleder på Interskolen i Viby Thomas Kilsmark.
#
# Så det er effektivt, økonomisk samt har den rette kvalitet.
#
# Sædvanligvis 15 mg pr. kg legemsvægt højst 4 gange i døgnet.
#
# Så er jeg fri for stearin over det hele nemlig..
#
# Så fik vi endelig slået hul på sæsonen 2008.
#
# Så hårdt trækker kommunikationsdirektør Jan Wildau i Arriva fronten op.
#
# Så slipper man for at ryste Matilde, inden den drikkes.
#
# Så startes der op igen fredag med hele 6 prøver.
#
# Se denne kutter i listen Reddet af fiskere i Nordsøen.
#
# Selskabet har flere gange fulgt op på forholdene overfor SKAT.
#
# Selv en amerikansk præsident er blevet oplyst ved et spejlsyn.
#
# Sierra Leone har, i princippet, gratis skolegang for de yngre årgange.
#
# Sigtemidler: Hæren er også ved at anskaffe en pakke af sigtemidler.
#
# Skab et hjem med et naturligt udseende med dette tapet.
#
# Skrevet den november 23rd, 2011 at 12:57 Hej.
#
# Skyl forårsløgene og skær dem i ringe, også det grønne.
#
# Snefnug-perleplader og æbleskiver Dette indlæg blev udgivet i Små glimt.
#
# Som grundregel kan man lade vinen følge "hovedingrediensen" i suppen.
#
# Som udgangspunkt kan alle låne penge hos de forskellige låneselskaber.
#
# Søren Søndergaard, MEP for Folkebevægelsen mod EU, glæder sig over sammenbruddet.
#
# Sportsbranchen havde en omsætningstilbagegang på 2,3 pct. i december måned.
#
# Startskuddet gik og jeg lagde mig oppe i den forreste gruppe.
#
# Stemningsbilleder fra Sankt Hans festen på Hestehovedet i 1993.
#
# Stencirklen har en flot beliggenhed på et højdedrag mellem to søer.
#
# Stk. 4. Loven gælder endvidere for partnerbytte af ustøttede kone.
#
# Stk. 7 - Forældre/værge til medlemmer u. 15 har én stemme.
#
# Svar: For det første skal I lige undersøge opsigelsesvarslet i jeres..
#
# Tæret jernpram 35 meter lang med 2 store åbne lastrum.
#
# Tags: Danmark, Freyja, Jul, Snik Snak Send med e-mailBlog om dette!
#
# Tanja er en stor juleentusiast, der fra starten vidste, at hun..
#
# Tasken kan hænges op i det todelte karabinsæt som medfølger.
#
# Team Essex kørte sig fra ottende til tredjepladsen på Nürburgring.
#
# Til IMC findes der i dag ekstramoduler til 20 forskellige opgavetyper.
#
# Tilsæt Agro Bizz Diflufenican-2 og fyld op med den resterende vandmængde.
#
# Til sammenligning koster bodylabs whey protein 0,163 kr pr.
#
# To minutter senere høvlede Ronnie Schwartz bolden over fra tæt hold.
#
# Uddrag af "Aktuelt fra Socialministeriet, oktober 1998" (bilag 78/1998).
#
# Udover skabelonen skal du vedhæfte tre mp3 eller m4a-filer.
#
# Udvalget af aktiviteter var udformet, så alle kunne være med.
#
# Ulemper er nu de høje pollental fra hassel og el.
#
# Ulykker kan ske alle vegne - også på jeres arbejdsplads.
#
# Under disse principper vil en række redskabstyper tages i brug.
#
# Undervejs er personerne blevet forøget med nye 20-29 årige.
#
# Vælge et år fra Hedensted Brandvæsen du vil se billeder fra.
#
# Valget faldt på en lidt hjemmestrikket ide om en thanksgiving burger.
#
# Vandrestave er rigtig gode at have ved krydsning af vandløb!
#
# Varerne bør laves til færdigretter (koges eller steges) og fryses igen.
#
# Vector handler om at du skal væk fra "Big Brother".
#
# Ved brug af billederne skal COWI A/S angives som kilde.
#
# Vejnettet omkring Gatten er slet ikke gearet til den trafik.
#
# Vi bruger altid sæsonens bedste varer og af højeste kvalitet.
#
# Vi bruger den samme fælde til svampesporene som til pollen.
#
# Vi designer logo m.m. og monterer på ALT der kører.
#
# Vil du hï¿½re mere om projektet sï¿½ kontakt Henriette og Lene.
#
# Vi ser nu endelig frem til et nyt lækkert hus.
#
# Vi studerer alle fænomener, medens vi forsigtigt går frem gennem livet.
#
# Vi tager forbhold for ovenstående pris indtil denne er vedtaget.
#
# Vi vil ikke opfordre til, at man ikke køber juletræer.
#
# Vi vil understrege, at det er kritisabelt, det han har foretaget.

# %%
for i in LIXEasyList:
    print(i)
# Out:
# 31-årige Totti stod for begge mål.
#
# Abba tølter bare nemt derud af.
#
# ADD kunne derved ikke teste ham.
#
# At den kan evt.
#
# Bag salget står et..
#
# Begge koster 419,- pr. stk.
#
# Berg har plads til unge.
#
# De blev budt på:
#
# De er jo yngre end mine børn.
#
# Delte blade med hel rand.
#
# Dem vil i have igen.
#
# Den klæder dig smukt.
#
# Denne lille mus..
#
# Den skal også vide, det er jul.
#
# Den skål var brav, hurra!
#
# Der bruger jeg alt for mange penge.
#
# Der er da noget for enhver smag.
#
# Der er som jeg sagde.
#
# Der findes ingen brønd.
#
# "Der lød et kæmpe brag.
#
# Der må være noget bedre?
#
# Der skal sås lige inden frost.
#
# Der sker ikke noget i hvert fald..
#
# Det blev ikke til mere.”
#
# Det ene kammer er sat til test.
#
# Det er bare en super smuk ramme.
#
# Det er en skøn plet for to..
#
# Det er jo så flot tøj.
#
# Det er lige haram.
#
# Det er lige til citat!
#
# Det er noget, vi ved.”
#
# Det er rigtig mange penge for mig.
#
# Det er sgu lidt surt.
#
# Det gør det noget dyrere mht.
#
# Det her er sandt!
#
# Det kan laves meget nemt med PHP.
#
# Det klares via tlf. eller mail.
#
# Det må man sige de kunne.
#
# Det sidste var Eugen Mærsk.
#
# Det sket på 4 sek.
#
# Det tales der nemlig slet ikke om.
#
# Dette kan først ske fra 2001.
#
# Det virker nemlig rigtig godt.
#
# Ekstra barn koster 95,- kr.
#
# Èn aften om ugen i fem uger.
#
# En kort og præcis tekst.
#
# En rigtig stiv kæmpe!
#
# Er meget stolte af jer!
#
# Fie) har fået noget.
#
# Fine, fine sager siger jeg bare.
#
# Gud er vores Herre, såvel som jeres.
#
# Håber mit knæ virker igen.
#
# Håber nogen kan hjælpe mig på vej.
#
# Han kom ikke med ét råd!
#
# Han lader sig bare slæbe med.
#
# Han lever over måde.
#
# Han vil undgaa Dem.
#
# Her skulle jeg bo nu.
#
# Hunden skal NOK finde dem!
#
# Huset ligger på ejers grund.
#
# Hvis du kigger på min bil nu..
#
# Hvis du vil se mere.
#
# Hvor køber jeg en i DK.
#
# Hvor længe rejste du der?
#
# I år er HÅBET sat i fokus.
#
# Ikke alle kan sige alt.
#
# Ikke noget at være stolt af.
#
# Ja, det gør ondt at høre.
#
# Ja, det var en stærk tid.
#
# ”Ja, mor, vi har prøvet alt.
#
# Jeg er enig med hvad anonym siger.
#
# Jeg er selv ret så stolt!
#
# Jeg falder af og lander med al.
#
# Jeg glæder mig, til I kigger forbi.
#
# Jeg har nu heller aldrig prøvet det.
#
# Jeg havde den Lykke at dø ung."
#
# Jeg kan ikke regne det ud..
#
# "Jeg ønsker mig sådan"
#
# Jeg synes ikke jeg kan finde det.
#
# Kan komme nogle år før eller efter.
#
# Kolohe er lavet af nylon og metal.
#
# Kunne godt tænke mig det røde sæt.
#
# Læs det her digt.
#
# Læs mere om dette her under.
#
# Lidt slidt bind. 75 kr.
#
# Lidt sne til aften.
#
# Lyng og mos blev brugt meget.
#
# Man har fundet (jf.
#
# Meget fin stand, men med lidt støv!
#
# Men ikke med at tabe, siger Frank.
#
# Men indtil videre anede ingen uråd.
#
# Men løbe skal jeg!
#
# Mit link vil altså ikke blive sort?
#
# Nej, der er ingen regler herom.
#
# NF1 bør ikke at fylde så meget.
#
# Og altid flere øjne.
#
# Og det kan man lide i EU.
#
# Og det koster penge at komme ind.
#
# Og håber at du vil med?
#
# Og jeg går altid i gang.
#
# Og lille Kong vil gerne hjælpe ham.
#
# Og ordet fra himlen lød: Hør ham!
#
# Prisen udgør 30 kr. pr spil.
#
# Robert Fisk: Vær bange!
#
# Sådan her ser bogen ud.
#
# Så derfor skal der intet købes.
#
# Så jeg måtte sænke farten lidt.
#
# Så kommer der en drage.
#
# Salsa er kommet for at blive.
#
# Så tager jeg bindet fra dine øjne.
#
# Så vidt jeg kan forstå på det.
#
# Sensei Renï¿½ ser jo stadig godt ud.
#
# Se så, hvad der sker.
#
# Sølv eller sort.
#
# Stod meget lavt kl.
#
# Super fint, tænker jeg.
#
# Tænker bare når fx.
#
# Tak fordi du kom..!
#
# Tak for sidst Ann!
#
# Tak mvh Filip Hej.
#
# Tak skal du have Tina!
#
# Tror snart jeg vil på ferie dér.
#
# Vi kalder det "Why".
#
# Vil du se en panda blive født?
#
# Vi tror det lykkes igen!

# %%
for sentence in file_2_list:
    #print(sentence)
        
    # replace numbers and commas with spaces
    sentenceForLix = re.sub('[",:;()/\-?!.]', " ", sentence)
    sentenceForLix = re.sub("[0-9]+.?[0-9]*", " ", sentence)
    
    # compute LIX score
    LIX = ComputeLIXscoreOfPhrase(sentenceForLix)
    
    if LIX > 60:
        LIXDifficultScores.append(LIX)
        LIXDifficultList.append(sentence)
    elif LIX < 30: 
        LIXEasyScores.append(LIX)
        LIXEasyList.append(sentence)
    elif LIX > 40 and LIX < 50:
        LIXMediumScores.append(LIX)
        LIXMediumList.append(sentence)
        
        
print('Difficult: ', len(set(LIXDifficultList)))
print('Medium: ', len(set(LIXMediumList)))
print('Easy: ', len(set(LIXEasyList)))

# %%
# visualize score distribution
plt.hist(LIXDifficultScores, label='difficult')
plt.hist(LIXMediumScores, label='medium')
plt.hist(LIXEasyScores, label='easy')
plt.legend()

# %%
with open(resultPath + '\\' + 'difficult.txt', "w+", encoding='utf-8')  as file:    
    if LIXDifficultList:
        LIXDifficultList = set(LIXDifficultList)
        file.write("\n".join(LIXDifficultList))
    
#with open(resultPath + '\\' + 'medium.txt', "w+", encoding='utf-8')  as file:
#    if LIXMediumList:
#        LIXMediumList = set(LIXMediumList)
#        file.write("\n".join(LIXMediumList))
    
with open(resultPath + '\\' + 'easy.txt', "w+", encoding='utf-8') as file:
    if LIXEasyList:
        LIXEasyList = set(LIXEasyList)
        file.write("\n".join(LIXEasyList))

# %%
# Currently, the number of sentences in each category of complexity are 55,68,56. If 4 parts are created, they are 
# more or less equally distributed. 1 sentence will be removed from each part, to form two sets of trial sentences.  
# This part of code will take the 4 numbers 1-4, and create a combination of easy, medium and difficult sentences.

nParticipants = 4
combination1category  = 0
combiDifficult = list()
combiEasy = list()

for i in range(20):
    combination1categoryDifficult = str(random.randint(1,5)) + str(random.randint(1,5)) + str(random.randint(1,5)) + str(random.randint(1,5)) + str(random.randint(1,5))
    
    #print(combination1category)
    combiDifficult.append(combination1categoryDifficult)
    
    
for i in range(20):
    combination1categoryEasy = str(random.randint(1,5)) + str(random.randint(1,5)) + str(random.randint(1,5)) + str(random.randint(1,5)) + str(random.randint(1,5))
    
    #print(combination1category)
    combiEasy.append(combination1categoryEasy)
    
    

print(set(combiDifficult))
print(set(combiEasy))

# {'221', '341', '222', '323', '124', '143', '243', '311', '244', '121', '441', '211', '223', '344', '111', 
# '421', '331', '423', '342', '132'}
# Out:
# {'25325', '11543', '55415', '51522', '15121', '32132', '55545', '55423', '25554', '44543', '55431', '32225', '55325', '52512', '42535', '34423', '33123', '34312', '52135', '53513'}
# {'24324', '41125', '33513', '12511', '54255', '12324', '25253', '43232', '11242', '14324', '13551', '44242', '45431', '24123', '35322', '13121', '23311', '22542', '12255', '21431'}

# %%
# Randomized easy(1) and difficult(2)

p1 = list()
for i in range(5):
    level = str(random.randint(1,2))
    p1.append(level)
    
print(p1)
# Out:
# ['1', '1', '2', '1', '2']

# %%
# part is a variable that determines the part of the category to be taken, for the participant
part = {'easy' : 4}
part['medium'] =  4
part['difficult'] = 1
nPhrases = 5

participant = 'Björgvin_2'


infilePath = r'\\ait-pdfs.win.dtu.dk\users\homedir\taba\Documents\Experiment design\Danish sentences\VISL Sentences - Study1\Analyzed\Danish\Parts'
outfilePath = r'\\ait-pdfs.win.dtu.dk\users\homedir\taba\Documents\Experiment design\Pilot expt for movement\Phrases'

fileEasy = 'easy' + str(part['easy']) + '.txt'
fileMedium = 'medium' + str(part['medium']) + '.txt'
fileDifficult = 'difficult' + str(part['difficult']) + '.txt'
    
# open file and choose 5 sentences randomly
with open(infilePath + '\\' + fileEasy, 'r', encoding='utf-8') as f_easy:
    phrases_easy_all = f_easy.read().splitlines()

with open(infilePath + '\\' + fileMedium, 'r', encoding='utf-8') as f_medium:
    phrases_medium_all = f_medium.read().splitlines()

with open(infilePath + '\\' + fileDifficult, 'r', encoding='utf-8') as f_difficult:
    phrases_difficult_all = f_difficult.read().splitlines()

# choose nPhrases number of random sentences from each category
phrases_easy_some = random.sample(phrases_easy_all, nPhrases)
phrases_medium_some = random.sample(phrases_medium_all, nPhrases)
phrases_difficult_some = random.sample(phrases_difficult_all, nPhrases)

phrasesFinal = phrases_easy_some + phrases_medium_some + phrases_difficult_some

# write the phrases in a text file 
with open(outfilePath + '\\' + participant + '.txt', 'w+', encoding='utf-8') as f_out:
    f_out.write('\n'.join(phrasesFinal))

# %%
a = ComputeLIXscoreOfPhrase('It validates people''s lives.')

# %%
a
# Out:
# 69.66666666666667
